# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.express as px

# %%
data_train = pd.read_csv('/Users/bartlomiejszafran/Desktop/archive/DailyDelhiClimateTrain.csv')

# %%
data_train.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
data_train.describe()
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
figure = px.line(data_train, x='date', y='meantemp')
figure.show()

# %%
figure = px.line(data_train, x='date', y='humidity')
figure.show()

# %%
figure = px.line(data_train, x='date', y='wind_speed')
figure.show()

# %%
figure = px.line(data_train, x='date', y='meanpressure')
figure.show()

# %%
figure = px.scatter(data_frame = data_train, x="humidity", y="meantemp", size="meantemp", trendline="lowess", title = "Relationship Between Temperature and Humidity")
figure.show()

# %%
data_train["date"] = pd.to_datetime(data_train["date"], format = '%Y-%m-%d')
data_train['year'] = data_train['date'].dt.year
data_train["month"] = data_train["date"].dt.month
data_train.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1

# %%
plt.style.use('dark_background')
plt.figure(figsize=(15, 10))
plt.title("Temperature Change in Delhi Over the Years")
sns.lineplot(data = data_train, x='month', y='meantemp', hue='year')
plt.show()

# %%
forecast_data = data_train.rename(columns = {"date": "ds", "meantemp": "y"})
print(forecast_data)
# Out:
#              ds          y    humidity  wind_speed  meanpressure  year  month
# 0    2013-01-01  10.000000   84.500000    0.000000   1015.666667  2013      1
# 1    2013-01-02   7.400000   92.000000    2.980000   1017.800000  2013      1
# 2    2013-01-03   7.166667   87.000000    4.633333   1018.666667  2013      1
# 3    2013-01-04   8.666667   71.333333    1.233333   1017.166667  2013      1
# 4    2013-01-05   6.000000   86.833333    3.700000   1016.500000  2013      1
# ...         ...        ...         ...         ...           ...   ...    ...
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217  2016     12
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762  2016     12
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762  2016     12
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000  2016     12
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000  2017      1
#
# [1462 rows x 7 columns]

# %%
pip install prophet
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 9.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.9/642.9 kB 9.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 11.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.2 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=731999 sha256=cdf0578b44a9bcff7824bac6e7e9406d237082c88e2285ea27e13e3fc3662c78
#   Stored in directory: /Users/bartlomiejszafran/Library/Caches/pip/wheels/d6/67/78/aa2e8d108639dd23a5e9e72a4fc88bb44f5541894382712f48
# Successfully built pymeeus
# ...

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
model = Prophet()
model.fit(forecast_data)
forecasts = model.make_future_dataframe(periods=1825)
predictions = model.predict(forecasts)
plot_plotly(model, predictions)
# Out:
# 14:10:55 - cmdstanpy - INFO - Chain [1] start processing
# 14:10:56 - cmdstanpy - INFO - Chain [1] done processing
